# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# ## "My Jupyter Notebook on IBM Watson Studio"

# %% [markdown]
# ## NITHIN GEORGE
# Working as Travel consultant and need to change my career as Data Analyst

# %% [markdown]
# ## "I am interested in data science because this is the most demanded job in the current age, i have a strong data analysis skill so i think i can success in this field".

# %% [markdown]
# ## adding two numbers (one and two) and looking for the result as 3

# %%
one = 1
two = 2
print(one + two )
# Out:
# 3

# %% [markdown]
# ## attached image ![bl-caf-fl-02.jpeg](attachment:c03efaa5-7e2f-429e-a803-5e871c4d4bca.jpeg)
# 33[link text] (https://www.google.com/
# ## numberd list of places
# 1. New York
# 2. Washington
# 3. Las vegas
# 4. Los Angeles
